# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\raobr\Documents\Project Files\Notebooks and Datasets\Narrativity in Scientific Publishing\narrativity-in-scientific-publishing\PLOS_narrativity.csv")

data.head()
# Out:
#    Unnamed: 0  X_unit_id        X_created_at        X_id        X_started_at  \
# 0           1  886110198  2/19/2016 00:11:58  1898740971  2/19/2016 00:04:22
# 1           2  886110198  2/19/2016 00:21:48  1898749020  2/19/2016 00:15:03
# 2           3  886110198  2/19/2016 00:38:40  1898760130  2/19/2016 00:19:16
# 3           4  886110198  2/19/2016 01:08:54  1898775228  2/19/2016 01:04:05
# 4           5  886110198  2/19/2016 01:25:11  1898784119  2/19/2016 01:22:23
#
#    X_tainted   X_channel  X_trust  X_worker_id X_country  \
# 0      False  coinworker        1     36180653       USA
# 1      False  coinworker        1     36180771       USA
# 2      False       elite        1     36514787       AUS
# 3      False      neodev        1     33714737       USA
# 4      False     instagc        1     30108041       USA
#
#                 ...                  sn   ti   ut  vl  z9  cin_mas  \
# 0               ...                 NaN  NaN  NaN NaN NaN     37.0
# ...
